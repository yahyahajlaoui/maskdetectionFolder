# %% [markdown]
# #  Import Dependencies

# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in d:\tfod\tfodcourse\tfod\lib\site-packages (4.5.3.56)
# Requirement already satisfied: numpy>=1.17.3 in d:\tfod\tfodcourse\tfod\lib\site-packages (from opencv-python) (1.19.2)

# %%
# Import opencv
import cv2 

# Import uuid
import uuid

# Import Operating System
import os

# Import time
import time

# %% [markdown]
# #  Define Images to Collect

# %%
labels = ['mask', 'nomask']
number_imgs = 3

# %% [markdown]
# # Setup Folders

# %%
IMAGES_PATH = os.path.join('Tensorflow', 'workspace', 'images', 'collectedimages')

# %%
if not os.path.exists(IMAGES_PATH):
    if os.name == 'posix':
        # !mkdir -p {IMAGES_PATH}
    if os.name == 'nt':
         # !mkdir {IMAGES_PATH}
for label in labels:
    path = os.path.join(IMAGES_PATH, label)
    if not os.path.exists(path):
        # !mkdir {path}

# %% [markdown]
# # Capture Images

# %%
for label in labels:
    cap = cv2.VideoCapture(0)
    print('Collecting images for {}'.format(label))
    time.sleep(5)
    for imgnum in range(number_imgs):
        print('Collecting image {}'.format(imgnum))
        ret, frame = cap.read()
        imgname = os.path.join(IMAGES_PATH,label,label+'.'+'{}.jpg'.format(str(uuid.uuid1())))
        cv2.imwrite(imgname, frame)
        cv2.imshow('frame', frame)
        time.sleep(5)

        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
cap.release()
cv2.destroyAllWindows()
# Out:
# Collecting images for mask
# Collecting image 0
# Collecting image 1
# Collecting image 2
# Collecting images for nomask
# Collecting image 0
# Collecting image 1
# Collecting image 2

# %% [markdown]
# # Image Labelling

# %%
# !pip install --upgrade pyqt5 lxml
# Out:
# Requirement already satisfied: pyqt5 in d:\tfod\tfodcourse\tfod\lib\site-packages (5.15.4)
# Requirement already satisfied: lxml in d:\tfod\tfodcourse\tfod\lib\site-packages (4.6.3)
# Requirement already satisfied: PyQt5-Qt5>=5.15 in d:\tfod\tfodcourse\tfod\lib\site-packages (from pyqt5) (5.15.2)
# Requirement already satisfied: PyQt5-sip<13,>=12.8 in d:\tfod\tfodcourse\tfod\lib\site-packages (from pyqt5) (12.9.0)

# %%
LABELIMG_PATH = os.path.join('Tensorflow', 'labelimg')

# %%
# !pip list
# Out:
# Package                            Version             Location
# ---------------------------------- ------------------- --------------------------------------------------
# absl-py                            0.13.0
# alabaster                          0.7.12
# anaconda-client                    1.7.2
# anaconda-navigator                 1.10.0
# anaconda-project                   0.8.3
# apache-beam                        2.31.0
# argh                               0.26.2
# argon2-cffi                        20.1.0
# asn1crypto                         1.4.0
# astroid                            2.4.2
# astropy                            4.0.2
# astunparse                         1.6.3
# async-generator                    1.10
# atomicwrites                       1.4.0
# attrs                              20.3.0
# autopep8                           1.5.4
# avro-python3                       1.10.2
# Babel                              2.8.1
# backcall                           0.2.0
# backports.functools-lru-cache      1.6.1
# backports.shutil-get-terminal-size 1.0.0
# backports.tempfile                 1.0
# backports.weakref                  1.0.post1
# bcrypt                             3.2.0
# beautifulsoup4                     4.9.3
# bitarray                           1.6.1
# bkcharts                           0.2
# bleach                             3.2.1
# bokeh                              2.2.3
# boto                               2.49.0
# Bottleneck                         1.3.2
# brotlipy                           0.7.0
# cachetools                         4.2.2
# certifi                            2020.6.20
# cffi                               1.14.3
# chardet                            3.0.4
# click                              7.1.2
# cloudpickle                        1.6.0
# clyent                             1.2.2
# colorama                           0.4.4
# comtypes                           1.1.7
# conda                              4.10.3
# conda-build                        3.20.5
# conda-package-handling             1.7.2
# conda-verify                       3.4.2
# contextlib2                        0.6.0.post1
# crcmod                             1.7
# cryptography                       3.1.1
# cycler                             0.10.0
# Cython                             0.29.21
# cytoolz                            0.11.0
# dask                               2.30.0
# debugpy                            1.4.0
# decorator                          5.0.9
# defusedxml                         0.6.0
# diff-match-patch                   20200713
# dill                               0.3.1.1
# distributed                        2.30.1
# dm-tree                            0.1.6
# docopt                             0.6.2
# docutils                           0.16
# entrypoints                        0.3
# et-xmlfile                         1.0.1
# fastavro                           1.4.3
# fastcache                          1.1.0
# filelock                           3.0.12
# flake8                             3.8.4
# Flask                              1.1.2
# flatbuffers                        1.12
# fsspec                             0.8.3
# future                             0.18.2
# gast                               0.4.0
# gevent                             20.9.0
# gin-config                         0.4.0
# glob2                              0.7
# google-api-core                    1.31.0
# google-api-python-client           2.14.0
# google-auth                        1.33.1
# google-auth-httplib2               0.1.0
# google-auth-oauthlib               0.4.4
# google-cloud-bigquery              1.21.0
# google-cloud-core                  1.7.1
# google-pasta                       0.2.0
# google-resumable-media             0.4.1
# googleapis-common-protos           1.53.0
# greenlet                           0.4.17
# grpcio                             1.34.1
# h5py                               3.1.0
# hdfs                               2.6.0
# HeapDict                           1.0.1
# html5lib                           1.1
# httplib2                           0.19.1
# idna                               2.10
# imageio                            2.9.0
# imagesize                          1.2.0
# importlib-metadata                 2.0.0
# importlib-resources                5.2.0
# iniconfig                          1.1.1
# intervaltree                       3.1.0
# ipykernel                          6.0.3
# ipython                            7.25.0
# ipython-genutils                   0.2.0
# ipywidgets                         7.5.1
# isort                              5.6.4
# itsdangerous                       1.1.0
# jdcal                              1.4.1
# jedi                               0.18.0
# Jinja2                             2.11.2
# joblib                             0.17.0
# json5                              0.9.5
# jsonschema                         3.2.0
# jupyter                            1.0.0
# jupyter-client                     6.1.12
# jupyter-console                    6.2.0
# jupyter-core                       4.7.1
# jupyterlab                         2.2.6
# jupyterlab-pygments                0.1.2
# jupyterlab-server                  1.2.0
# kaggle                             1.5.12
# keras-nightly                      2.5.0.dev2021032900
# Keras-Preprocessing                1.1.2
# keyring                            21.4.0
# kiwisolver                         1.3.0
# lazy-object-proxy                  1.4.3
# libarchive-c                       2.9
# llvmlite                           0.34.0
# locket                             0.2.0
# lvis                               0.5.3
# lxml                               4.6.3
# Markdown                           3.3.4
# MarkupSafe                         1.1.1
# matplotlib                         3.3.2
# matplotlib-inline                  0.1.2
# mccabe                             0.6.1
# menuinst                           1.4.16
# mistune                            0.8.4
# mkl-fft                            1.2.0
# mkl-random                         1.1.1
# mkl-service                        2.3.0
# mock                               4.0.2
# more-itertools                     8.6.0
# mpmath                             1.1.0
# msgpack                            1.0.0
# multipledispatch                   0.6.0
# navigator-updater                  0.2.1
# nbclient                           0.5.1
# nbconvert                          6.0.7
# nbformat                           5.0.8
# nest-asyncio                       1.4.2
# networkx                           2.5
# nltk                               3.5
# nose                               1.3.7
# notebook                           6.1.4
# numba                              0.51.2
# numexpr                            2.7.1
# numpy                              1.19.2
# numpydoc                           1.1.0
# oauth2client                       4.1.3
# oauthlib                           3.1.1
# object-detection                   0.1
# olefile                            0.46
# opencv-contrib-python              4.5.3.56
# opencv-python                      4.5.3.56
# opencv-python-headless             4.5.3.56
# openpyxl                           3.0.5
# opt-einsum                         3.3.0
# packaging                          20.4
# pandas                             1.1.3
# pandocfilters                      1.4.3
# paramiko                           2.7.2
# parso                              0.8.2
# partd                              1.1.0
# path                               15.0.0
# pathlib2                           2.3.5
# pathtools                          0.1.2
# patsy                              0.5.1
# pep8                               1.7.1
# pexpect                            4.8.0
# pickleshare                        0.7.5
# Pillow                             8.0.1
# pip                                21.1.3
# pkginfo                            1.6.1
# pluggy                             0.13.1
# ply                                3.11
# portalocker                        2.0.0
# prometheus-client                  0.8.0
# promise                            2.3
# prompt-toolkit                     3.0.19
# protobuf                           3.17.3
# psutil                             5.7.2
# py                                 1.9.0
# py-cpuinfo                         8.0.0
# pyarrow                            4.0.1
# pyasn1                             0.4.8
# pyasn1-modules                     0.2.8
# pycocotools                        2.0.2
# pycodestyle                        2.6.0
# pycosat                            0.6.3
# pycparser                          2.20
# pycurl                             7.43.0.6
# pydocstyle                         5.1.1
# pydot                              1.4.2
# pyflakes                           2.2.0
# Pygments                           2.9.0
# pylint                             2.6.0
# pymongo                            3.12.0
# PyNaCl                             1.4.0
# pyodbc                             4.0.0-unsupported
# pyOpenSSL                          19.1.0
# pyparsing                          2.4.7
# PyQt5                              5.15.4
# PyQt5-Qt5                          5.15.2
# PyQt5-sip                          12.9.0
# pyreadline                         2.1
# pyrsistent                         0.17.3
# PySocks                            1.7.1
# pytest                             0.0.0
# python-dateutil                    2.8.2
# python-jsonrpc-server              0.4.0
# python-language-server             0.35.1
# python-slugify                     5.0.2
# pytz                               2020.1
# PyWavelets                         1.1.1
# pywin32                            301
# pywin32-ctypes                     0.2.0
# pywinpty                           0.5.7
# PyYAML                             5.3.1
# pyzmq                              22.1.0
# QDarkStyle                         2.8.1
# QtAwesome                          1.0.1
# qtconsole                          4.7.7
# QtPy                               1.9.0
# regex                              2020.10.15
# requests                           2.24.0
# requests-oauthlib                  1.3.0
# rope                               0.18.0
# rsa                                4.7.2
# Rtree                              0.9.4
# ruamel-yaml                        0.15.87
# sacrebleu                          1.5.1
# scikit-image                       0.17.2
# scikit-learn                       0.23.2
# scipy                              1.5.2
# seaborn                            0.11.0
# Send2Trash                         1.5.0
# sentencepiece                      0.1.96
# seqeval                            1.2.2
# setuptools                         50.3.1.post20201107
# simplegeneric                      0.8.1
# singledispatch                     3.4.0.3
# sip                                4.19.13
# six                                1.16.0
# slim                               0.1                 d:\tfod\tfodcourse\tensorflow\models\research\slim
# snowballstemmer                    2.0.0
# sortedcollections                  1.2.1
# sortedcontainers                   2.2.2
# soupsieve                          2.0.1
# Sphinx                             3.2.1
# sphinxcontrib-applehelp            1.0.2
# sphinxcontrib-devhelp              1.0.2
# sphinxcontrib-htmlhelp             1.0.3
# sphinxcontrib-jsmath               1.0.1
# sphinxcontrib-qthelp               1.0.3
# sphinxcontrib-serializinghtml      1.1.4
# sphinxcontrib-websupport           1.2.4
# spyder                             4.1.5
# spyder-kernels                     1.9.4
# SQLAlchemy                         1.3.20
# statsmodels                        0.12.0
# sympy                              1.6.2
# tables                             3.6.1
# tblib                              1.7.0
# tensorboard                        2.5.0
# tensorboard-data-server            0.6.1
# tensorboard-plugin-wit             1.8.0
# tensorflow                         2.5.0
# tensorflow-addons                  0.13.0
# tensorflow-datasets                4.3.0
# tensorflow-estimator               2.5.0
# tensorflow-hub                     0.12.0
# tensorflow-metadata                1.1.0
# tensorflow-model-optimization      0.6.0
# termcolor                          1.1.0
# terminado                          0.9.1
# testpath                           0.4.4
# text-unidecode                     1.3
# tf-models-official                 2.5.0
# tf-slim                            1.1.0
# threadpoolctl                      2.1.0
# tifffile                           2020.10.1
# toml                               0.10.1
# toolz                              0.11.1
# tornado                            6.1
# tqdm                               4.50.2
# traitlets                          5.0.5
# typeguard                          2.12.1
# typing-extensions                  3.7.4.3
# ujson                              4.0.1
# unicodecsv                         0.14.1
# uritemplate                        3.0.1
# urllib3                            1.25.11
# watchdog                           0.10.3
# wcwidth                            0.2.5
# webencodings                       0.5.1
# Werkzeug                           1.0.1
# wget                               3.2
# wheel                              0.35.1
# widgetsnbextension                 3.5.1
# win-inet-pton                      1.1.0
# win-unicode-console                0.5
# wincertstore                       0.2
# wrapt                              1.12.1
# xlrd                               1.2.0
# XlsxWriter                         1.3.7
# xlwings                            0.20.8
# xlwt                               1.3.0
# xmltodict                          0.12.0
# yapf                               0.30.0
# zict                               2.0.0
# zipp                               3.4.0
# zope.event                         4.5.0
# zope.interface                     5.1.2

# %%
if not os.path.exists(LABELIMG_PATH):
    # !mkdir {LABELIMG_PATH}
    # !git clone https://github.com/tzutalin/labelImg {LABELIMG_PATH}

# %%
if os.name == 'posix':
    # !make qt5py3
if os.name =='nt':
    # !cd {LABELIMG_PATH} && pyrcc5 -o libs/resources.py resources.qrc

# %%
# !cd {LABELIMG_PATH} && python labelImg.py
# Out:
# Image:D:\tfod\TFODCourse\Tensorflow\workspace\images\collectedimages\mask\mask.1eafa5ea-eb45-11eb-b257-b4a9fc5fa040.jpg -> Annotation:D:/tfod/TFODCourse/Tensorflow/workspace/images/collectedimages/mask/mask.1eafa5ea-eb45-11eb-b257-b4a9fc5fa040.xml
# Image:D:\tfod\TFODCourse\Tensorflow\workspace\images\collectedimages\mask\mask.18b5cf25-eb45-11eb-b83c-b4a9fc5fa040.jpg -> Annotation:D:/tfod/TFODCourse/Tensorflow/workspace/images/collectedimages/mask/mask.18b5cf25-eb45-11eb-b83c-b4a9fc5fa040.xml
# Image:D:\tfod\TFODCourse\Tensorflow\workspace\images\collectedimages\mask\mask.24ae190a-eb45-11eb-80ed-b4a9fc5fa040.jpg -> Annotation:D:/tfod/TFODCourse/Tensorflow/workspace/images/collectedimages/mask/mask.24ae190a-eb45-11eb-80ed-b4a9fc5fa040.xml
# Image:D:\tfod\TFODCourse\Tensorflow\workspace\images\collectedimages\mask\mask.2aaac207-eb45-11eb-973f-b4a9fc5fa040.jpg -> Annotation:D:/tfod/TFODCourse/Tensorflow/workspace/images/collectedimages/mask/mask.2aaac207-eb45-11eb-973f-b4a9fc5fa040.xml
# Image:D:\tfod\TFODCourse\Tensorflow\workspace\images\collectedimages\nomask\nomask.3a33de68-eb45-11eb-b5ed-b4a9fc5fa040.jpg -> Annotation:D:/tfod/TFODCourse/Tensorflow/workspace/images/collectedimages/nomask/nomask.3a33de68-eb45-11eb-b5ed-b4a9fc5fa040.xml
# Image:D:\tfod\TFODCourse\Tensorflow\workspace\images\collectedimages\nomask\nomask.4c25b1d9-eb45-11eb-afa0-b4a9fc5fa040.jpg -> Annotation:D:/tfod/TFODCourse/Tensorflow/workspace/images/collectedimages/nomask/nomask.4c25b1d9-eb45-11eb-afa0-b4a9fc5fa040.xml
# Image:D:\tfod\TFODCourse\Tensorflow\workspace\images\collectedimages\nomask\nomask.402f21a1-eb45-11eb-ac40-b4a9fc5fa040.jpg -> Annotation:D:/tfod/TFODCourse/Tensorflow/workspace/images/collectedimages/nomask/nomask.402f21a1-eb45-11eb-ac40-b4a9fc5fa040.xml
# Cancel creation.
# Image:D:\tfod\TFODCourse\Tensorflow\workspace\images\collectedimages\nomask\nomask.462a8f38-eb45-11eb-89c2-b4a9fc5fa040.jpg -> Annotation:D:/tfod/TFODCourse/Tensorflow/workspace/images/collectedimages/nomask/nomask.462a8f38-eb45-11eb-89c2-b4a9fc5fa040.xml
